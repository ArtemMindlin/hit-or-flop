# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data_formatted.csv')

df_w_genres = pd.read_csv('../data_w_genres/data_w_genres_formatted.csv')

df_w_songs_genres = df.merge(df_w_genres[['artists','genres']], on='artists', how='inner')

# %%
df_w_songs_genres.to_csv('data_w_songs_genres.csv', index=False)
